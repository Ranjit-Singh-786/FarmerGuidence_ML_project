# %%
from ipywidgets import interact       # good libraries for project
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.naive_bayes import GaussianNB
import pickle

# %%
data=pd.read_csv('farmer.csv')
data.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
x = data.drop(labels='label', axis=1)
x
# Out:
#         N   P   K  temperature   humidity        ph    rainfall
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340
# ...   ...  ..  ..          ...        ...       ...         ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041
#
# [2200 rows x 7 columns]

# %%
y = data['label']
y
# Out:
# 0         rice
# 1         rice
# 2         rice
# 3         rice
# 4         rice
#          ...
# 2195    coffee
# 2196    coffee
# 2197    coffee
# 2198    coffee
# 2199    coffee
# Name: label, Length: 2200, dtype: object

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=31)

# %%
x_train
# Out:
#        N    P    K  temperature   humidity        ph    rainfall
# 845   24   61   17    22.637142  65.445449  6.233269   38.304111
# 812    3   69   23    28.674088  63.188330  7.299361   42.960186
# 1435  88   17   52    29.904159  90.752844  6.646962   25.378284
# 1845  39    7   29    27.542732  94.590861  6.362544  150.201214
# 71    67   45   38    22.727910  82.170688  7.300411  260.887506
# ...   ..  ...  ...          ...        ...       ...         ...
# 1276  25  129  195    17.986678  81.177121  5.777271   72.371277
# 28    60   49   44    20.775761  84.497744  6.244841  240.081065
# 826   32   56   18    20.046771  65.843953  7.135252   46.053331
# 2064  89   58   35    23.986517  82.090534  6.096839  167.057646
# 722   52   71   16    27.742748  68.539971  7.075886   71.786153
#
# [1760 rows x 7 columns]

# %%
x_test
# Out:
#         N   P   K  temperature   humidity        ph    rainfall
# 1159   29  35  28    28.347161  53.539031  6.967418   90.402604
# 499    33  61  24    20.046118  48.939056  4.567446  122.456420
# 1609   13  23   6    23.961476  90.264080  7.365338  102.695870
# 1924  125  39  21    25.031496  82.212766  7.954629   95.019132
# 661    30  44  16    29.730130  82.891664  6.442336   50.915113
# ...   ...  ..  ..          ...        ...       ...         ...
# 1374   81  16  45    26.904357  86.254262  6.727468   59.759800
# 1716   49  55  53    38.441872  93.637390  6.544030   77.715669
# 2121   83  21  28    25.567483  60.492446  7.466901  190.225784
# 1141   26  32  32    30.914715  49.929639  6.810186   90.140478
# 1645   40  22   6    24.536101  91.909972  6.488221  115.978799
#
# [440 rows x 7 columns]

# %%
y_train
# Out:
# 845        lentil
# 812        lentil
# 1435    muskmelon
# 1845      coconut
# 71           rice
#           ...
# 1276       grapes
# 28           rice
# 826        lentil
# 2064         jute
# 722     blackgram
# Name: label, Length: 1760, dtype: object

# %%
y_test
# Out:
# 1159         mango
# 499     pigeonpeas
# 1609        orange
# 1924        cotton
# 661       mungbean
#            ...
# 1374    watermelon
# 1716        papaya
# 2121        coffee
# 1141         mango
# 1645        orange
# Name: label, Length: 440, dtype: object

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((1760, 7), (440, 7), (1760,), (440,))

# %%
x_train.dtypes
# Out:
# N                int64
# P                int64
# K                int64
# temperature    float64
# humidity       float64
# ph             float64
# rainfall       float64
# dtype: object

# %%
x_test.dtypes
# Out:
# N                int64
# P                int64
# K                int64
# temperature    float64
# humidity       float64
# ph             float64
# rainfall       float64
# dtype: object

# %%
y_train.dtypes
# Out:
# dtype('O')

# %%
y_test.dtypes
# Out:
# dtype('O')

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# C:\Users\Ranjit Singh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.9477272727272728

# %%
gnb = GaussianNB()

# %%
gnb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
gnb.score(x_test,y_test)
# Out:
# 0.9977272727272727

# %%
gnb.score(x_train,y_train)
# Out:
# 0.9943181818181818

# %%
pickle.dump(gnb,open('farmermodel.pkl','wb'))

# %%
model = pickle.load(open('farmermodel.pkl','rb'))

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array(['mango', 'pigeonpeas', 'orange', 'cotton', 'mungbean', 'coconut',
#        'pigeonpeas', 'maize', 'watermelon', 'mango', 'apple', 'chickpea',
#        'pomegranate', 'coffee', 'papaya', 'grapes', 'apple', 'coconut',
#        'papaya', 'rice', 'jute', 'grapes', 'lentil', 'cotton', 'maize',
#        'coconut', 'pomegranate', 'mango', 'watermelon', 'jute', 'coconut',
#        'kidneybeans', 'banana', 'coconut', 'rice', 'pomegranate',
#        'blackgram', 'blackgram', 'pomegranate', 'jute', 'rice', 'lentil',
#        'papaya', 'pomegranate', 'kidneybeans', 'mungbean', 'chickpea',
#        'watermelon', 'lentil', 'coconut', 'mango', 'apple', 'grapes',
#        'blackgram', 'maize', 'muskmelon', 'mungbean', 'muskmelon',
#        'muskmelon', 'pomegranate', 'kidneybeans', 'lentil', 'rice',
#        'coconut', 'pigeonpeas', 'rice', 'grapes', 'coconut', 'coffee',
#        'maize', 'jute', 'pigeonpeas', 'mango', 'rice', 'rice',
# ...

# %%
pred = pd.DataFrame(y_pred)
pred
# Out:
#               0
# 0         mango
# 1    pigeonpeas
# 2        orange
# 3        cotton
# 4      mungbean
# ..          ...
# 435  watermelon
# 436      papaya
# 437      coffee
# 438       mango
# 439      orange
#
# [440 rows x 1 columns]

# %%
act = pd.DataFrame(y_test)
act
# Out:
#            label
# 1159       mango
# 499   pigeonpeas
# 1609      orange
# 1924      cotton
# 661     mungbean
# ...          ...
# 1374  watermelon
# 1716      papaya
# 2121      coffee
# 1141       mango
# 1645      orange
#
# [440 rows x 1 columns]

# %%
act['predicted']=pred[0].values

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
act
# Out:
#             label    predicted
# 1159        mango        mango
# 499    pigeonpeas   pigeonpeas
# 1609       orange       orange
# 1924       cotton       cotton
# 661      mungbean     mungbean
# 1839      coconut      coconut
# 475    pigeonpeas   pigeonpeas
# 141         maize        maize
# 1317   watermelon   watermelon
# 1107        mango        mango
# 1508        apple        apple
# 283      chickpea     chickpea
# 938   pomegranate  pomegranate
# 2129       coffee       coffee
# 1755       papaya       papaya
# 1293       grapes       grapes
# 1504        apple        apple
# 1873      coconut      coconut
# 1737       papaya       papaya
# 67           rice         rice
# 2085         jute         jute
# 1206       grapes       grapes
# 820        lentil       lentil
# 1975       cotton       cotton
# 112         maize        maize
# 1825      coconut      coconut
# 979   pomegranate  pomegranate
# 1143        mango        mango
# 1324   watermelon   watermelon
# ...

# %%
act['label'].value_counts()
# Out:
# watermelon     29
# rice           27
# chickpea       26
# papaya         23
# jute           23
# coconut        23
# maize          23
# apple          22
# coffee         21
# muskmelon      20
# banana         20
# mango          20
# cotton         20
# blackgram      19
# pomegranate    18
# lentil         18
# pigeonpeas     17
# mungbean       16
# kidneybeans    16
# mothbeans      16
# orange         12
# grapes         11
# Name: label, dtype: int64

# %%
act['predicted'].value_counts()
# Out:
# watermelon     29
# chickpea       26
# rice           26
# jute           24
# papaya         23
# coconut        23
# maize          23
# apple          22
# coffee         21
# muskmelon      20
# banana         20
# mango          20
# cotton         20
# blackgram      19
# pomegranate    18
# lentil         18
# pigeonpeas     17
# mungbean       16
# kidneybeans    16
# mothbeans      16
# orange         12
# grapes         11
# Name: predicted, dtype: int64

# %%
gnb.score(x_test,y_test)
# Out:
# 0.9977272727272727

# %%
pd.set_option('display.max_rows',15)

# %%
x_test.iloc[1].values
# Out:
# array([ 33.        ,  61.        ,  24.        ,  20.04611791,
#         48.93905624,   4.5674465 , 122.4564203 ])

# %%
result = model.predict([[ 33.        ,  61.        ,  24.        ,  20.0,
        48.9390,   4.567 , 122.45 ]])
# Out:
# C:\Users\Ranjit Singh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array(['pigeonpeas'], dtype='<U11')

# %%
type(result)
# Out:
# numpy.ndarray

# %%
result[0]
# Out:
# 'pigeonpeas'

# %%
x_train.dtypes
# Out:
# N                int64
# P                int64
# K                int64
# temperature    float64
# humidity       float64
# ph             float64
# rainfall       float64
# dtype: object

# %%
import pandas as pd

# %%
df = pd.read_csv('farmer.csv')
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
n - nitrogen
k - potesium
p - phosphurus
ph -hydrogen phosphurus

# %%
import pickle

# %%
model = pickle.load(open('farmermodel.pkl','rb'))

# %%
model.predict

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
result = model.predict([[ 33.        ,  100.        ,  240.        ,  20.0,
        48.9390,   20.567 , 100.45 ]])

# %%
result[0]
# Out:
# 'chickpea'

# %%
x_test.max()
# Out:
# N              140.000000
# P              145.000000
# K              205.000000
# temperature     42.933686
# humidity        99.724010
# ph               8.766129
# rainfall       280.404439
# dtype: float64

# %%
y_test.value_counts()
# Out:
# watermelon     29
# rice           27
# chickpea       26
# papaya         23
# jute           23
# coconut        23
# maize          23
# apple          22
# coffee         21
# muskmelon      20
# banana         20
# mango          20
# cotton         20
# blackgram      19
# pomegranate    18
# lentil         18
# pigeonpeas     17
# mungbean       16
# kidneybeans    16
# mothbeans      16
# orange         12
# grapes         11
# Name: label, dtype: int64

# %%
df[df['label']=='mothbeans'].mean()
# Out:
# N              21.440000
# P              48.010000
# K              20.230000
# temperature    28.194920
# humidity       53.160418
# ph              6.831174
# rainfall       51.198487
# dtype: float64
